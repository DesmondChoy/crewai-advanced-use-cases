# %% [markdown]
# # L1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# ## Import libs

# %%
# Warning control
import warnings
import os
import yaml
import pandas as pd

from dotenv import load_dotenv
from crewai import Agent, Task, Crew, Process
from typing import List
from pydantic import BaseModel, Field
from IPython.display import display, Markdown


load_dotenv()  # take environment variables from .env
warnings.filterwarnings("ignore")

os.environ["OPENAI_MODEL_NAME"] = "gpt-4o"

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {"agents": "config/agents.yaml", "tasks": "config/tasks.yaml"}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, "r") as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs["agents"]
tasks_config = configs["tasks"]

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(
        ..., description="Estimated time to complete the task in hours"
    )
    required_resources: List[str] = Field(
        ..., description="List of resources required to complete the task"
    )


class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(
        ..., description="List of task IDs associated with this milestone"
    )


class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(
        ..., description="List of tasks with their estimates"
    )
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(config=agents_config["project_planning_agent"])

estimation_agent = Agent(config=agents_config["estimation_agent"])

resource_allocation_agent = Agent(config=agents_config["resource_allocation_agent"])

# Creating Tasks
task_breakdown = Task(
    config=tasks_config["task_breakdown"], agent=project_planning_agent
)

time_resource_estimation = Task(
    config=tasks_config["time_resource_estimation"], agent=estimation_agent
)

resource_allocation = Task(
    config=tasks_config["resource_allocation"],
    agent=resource_allocation_agent,
    output_pydantic=ProjectPlan,  # This is the structured output we want
)

# Creating Crew
crew = Crew(
    agents=[project_planning_agent, estimation_agent, resource_allocation_agent],
    tasks=[task_breakdown, time_resource_estimation, resource_allocation],
    verbose=True,
)

# %% [markdown]
# ## Crew's Inputs

# %%
project = "Website"
industry = "Technology"
project_objectives = "Create a website for a small business"
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
    "project_type": project,
    "project_objectives": project_objectives,
    "industry": industry,
    "team_members": team_members,
    "project_requirements": project_requirements,
}

# Run the crew
result = crew.kickoff(inputs=inputs)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# **Website Project Breakdown and Timeline**
#
# 1. **Project Kickoff and Initial Planning**
#    - Task: Hold a project kickoff meeting with the team to discuss project goals, deliverables, and timelines.
#    - Responsible: John Doe (Project Manager)
#    - Duration: 1 day
#    - Dependencies: None
#    - Deliverables: Project plan and schedule
#
# 2. **Research and Wireframing**
#    - Task: Conduct research and create wireframes for the website layout.
#    - Responsible: Bob Smith (Designer)
#    - Duration: 3 days
#    - Dependencies: Project kickoff
#    - Deliverables: Wireframes for each page
#
# 3. **Responsive Design Development**
#    - Task: Design a responsive interface adaptable to both desktop and mobile devices.
#    - Responsible: Bob Smith (Designer)
#    - Duration: 5 days
#    - Dependencies: Completion of wireframes
#    - Deliverables: Responsive design mockups
#
# 4. **User Interface Design**
#    - Task: Implement a modern and clean user interface.
#    - Responsible: Bob Smith (Designer)
#    - Duration: 4 days
#    - Dependencies: Responsive design approval
#    - Deliverables: UI mockups
#
# 5. **Navigation System Development**
#    - Task: Develop a user-friendly navigation system.
#    - Responsible: Jane Doe (Software Engineer)
#    - Duration: 3 days
#    - Dependencies: UI design completion
#    - Deliverables: Functional navigation menu
#
# 6. **"About Us" Page Development**
#    - Task: Create the "About Us" page content and design.
#    - Responsible: Jane Doe (Software Engineer)
#    - Duration: 2 days
#    - Dependencies: UI design completion
#    - Deliverables: Completed "About Us" page
#
# 7. **"Services" Page Development**
#    - Task: Design and develop the "Services" page with descriptions.
#    - Responsible: Jane Doe (Software Engineer)
#    - Duration: 3 days
#    - Dependencies: UI design completion
#    - Deliverables: Completed "Services" page
#
# 8. **"Contact Us" Page Development**
#    - Task: Create a "Contact Us" page with a form and integrated map.
#    - Responsible: Jane Doe (Software Engineer)
#    - Duration: 4 days
#    - Dependencies: UI design completion
#    - Deliverables: Functional "Contact Us" page
#
# 9. **Blog Section Implementation**
#    - Task: Implement the blog section for news and updates.
#    - Responsible: Jane Doe (Software Engineer)
#    - Duration: 5 days
#    - Dependencies: UI design completion
#    - Deliverables: Working blog section
#
# 10. **Performance Optimization and SEO**
#     - Task: Ensure fast loading times and optimize the site for search engines.
#     - Responsible: Jane Doe (Software Engineer)
#     - Duration: 4 days
#     - Dependencies: Development completion
#     - Deliverables: SEO-optimized, fast-loading website
#
# 11. **Social Media Integration**
#     - Task: Integrate social media links and sharing capabilities.
#     - Responsible: Jane Doe (Software Engineer)
#     - Duration: 2 days
#     - Dependencies: UI design completion
#     - Deliverables: Integrated social media features
#
# 12. **Testimonials Section**
#     - Task: Create a section for customer testimonials.
#     - Responsible: Jane Doe (Software Engineer)
#     - Duration: 2 days
#     - Dependencies: UI design completion
#     - Deliverables: Working testimonials section
#
# 13. **Testing Phase**
#     - Task: Conduct comprehensive testing of all website features and design.
#     - Responsible: Alice Johnson and Tom Brown (QA Engineers)
#     - Duration: 5 days
#     - Dependencies: All development tasks completed
#     - Deliverables: Bug reports and functional prototype
#
# 14. **Bug Fixing and Final Adjustments**
#     - Task: Fix identified issues and make final design adjustments.
#     - Responsible: Jane Doe (Software Engineer)
#     - Duration: 3 days
#     - Dependencies: Testing phase completed
#     - Deliverables: Finalized website ready for launch
#
# 15. **Project Launch**
#     - Task: Launch the website after final approval.
#     - Responsible: John Doe (Project Manager)
#     - Duration: 1 day
#     - Dependencies: Bug fixing and adjustments
#     - Deliverables: Live website
#
# **Note:**
#
# - Timelines are estimates and might adjust based on real-time project dynamics.
# - Regular check-ins and stakeholder reviews are implicit throughout the project phases to ensure alignment and gather feedback.
#
# **Gantt Chart Timeline Visualization:**
#
# ```
# [Project Initialization and Planning]
# =========================== 1 day
# [Research and Wireframing]
# ==== 3 days
#
# [Design and Development Phase]
#
# Responsive Design --------------- 5 days
# ......................................
# UI Design ----------------------- 4 days
# ......................................
# Navigation ------------------ 3 days
# About Us ----------------- 2 days
# Services ------------------- 3 days
# Contact Us --------------- 4 days
# Blog Section --------------- 5 days
# Performance Optimizations ----------- 4 days
# Social Media Integration ------ 2 days
# Testimonials -------------- 2 days
#
# [Testing and Final Adjustments]
#
# Testing ============= 5 days
# Bug Fixing ============ 3 days
#
# [Project Launch]
# =========== 1 day
# ```
#
# The detailed task descriptions, timelines, and dependencies above can guide the team efficiently through the project life cycle, ensuring timely delivery and aligning with the targeted objectives.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# **Website Project Estimation Report**
#
# ---
#
# **1. Project Kickoff and Initial Planning**
# - **Duration:** 1 day
# - **Resources:** John Doe (Project Manager)
# - **Effort:** Minimal team effort, primarily organizational
# - **Risks/Uncertainties:** Low, as this task involves initial discussions only
#
# ---
#
# **2. Research and Wireframing**
# - **Duration:** 3 days
# - **Resources:** Bob Smith (Designer)
# - **Effort:** Medium - requires creativity and initial design iterations
# - **Risks/Uncertainties:** Medium - depends on the clarity of project goals and how aligned the team is
#
# ---
#
# **3. Responsive Design Development**
# - **Duration:** 5 days
# - **Resources:** Bob Smith (Designer)
# - **Effort:** High - design optimization for different devices
# - **Risks/Uncertainties:** Medium - could extend due to device compatibility concerns
#
# ---
#
# **4. User Interface Design**
# - **Duration:** 4 days
# - **Resources:** Bob Smith (Designer)
# - **Effort:** High - requires both aesthetic and functional elements
# - **Risks/Uncertainties:** Medium - possibility of revisions and stakeholder feedback
#
# ---
#
# **5. Navigation System Development**
# - **Duration:** 3 days
# - **Resources:** Jane Doe (Software Engineer)
# - **Effort:** Medium - involves both design and development
# - **Risks/Uncertainties:** Low - straightforward task given clear UI mockups
#
# ---
#
# **6. "About Us" Page Development**
# - **Duration:** 2 days
# - **Resources:** Jane Doe (Software Engineer)
# - **Effort:** Low - simple layout focusing on content
# - **Risks/Uncertainties:** Low - content ready before implementation
#
# ---
#
# **7. "Services" Page Development**
# - **Duration:** 3 days
# - **Resources:** Jane Doe (Software Engineer)
# - **Effort:** Low to Medium - standard information layout
# - **Risks/Uncertainties:** Low - fixed scope
#
# ---
#
# **8. "Contact Us" Page Development**
# - **Duration:** 4 days
# - **Resources:** Jane Doe (Software Engineer)
# - **Effort:** Medium - includes map and form integration
# - **Risks/Uncertainties:** Medium - challenges may arise from map APIs or form integration
#
# ---
#
# **9. Blog Section Implementation**
# - **Duration:** 5 days
# - **Resources:** Jane Doe (Software Engineer)
# - **Effort:** Medium to High - adaptable and expandable for future content
# - **Risks/Uncertainties:** Medium - dependent on CMS choice and configuration complexities
#
# ---
#
# **10. Performance Optimization and SEO**
# - **Duration:** 4 days
# - **Resources:** Jane Doe (Software Engineer)
# - **Effort:** High - intensive effort on fine-tuning performance
# - **Risks/Uncertainties:** High - SEO and performance are iterative processes that might require multiple trials
#
# ---
#
# **11. Social Media Integration**
# - **Duration:** 2 days
# - **Resources:** Jane Doe (Software Engineer)
# - **Effort:** Low - standard integration of social media links
# - **Risks/Uncertainties:** Low - consistent implementation is straight forward
#
# ---
#
# **12. Testimonials Section**
# - **Duration:** 2 days
# - **Resources:** Jane Doe (Software Engineer)
# - **Effort:** Low - primarily front-end work
# - **Risks/Uncertainties:** Low - limited complexity
#
# ---
#
# **13. Testing Phase**
# - **Duration:** 5 days
# - **Resources:** Alice Johnson and Tom Brown (QA Engineers)
# - **Effort:** High - comprehensive testing required to ensure quality
# - **Risks/Uncertainties:** Medium - risk of uncovering significant bugs that delay timelines
#
# ---
#
# **14. Bug Fixing and Final Adjustments**
# - **Duration:** 3 days
# - **Resources:** Jane Doe (Software Engineer)
# - **Effort:** High - fixes could vary based on the testing outcomes
# - **Risks/Uncertainties:** High - unexpected bugs and edge cases can arise
#
# ---
#
# **15. Project Launch**
# - **Duration:** 1 day
# - **Resources:** John Doe (Project Manager)
# - **Effort:** Minimal - coordination task
# - **Risks/Uncertainties:** Low - contingent on the success of previous milestones
#
# ---
#
# **Summary of Risks and Uncertainties:**
#
# - Tasks related to wireframing, responsive design, and UI design hold medium risks due to dependence on stakeholder feedback and creative variance.
# - Performance optimization and SEO present higher risks as they are iterative by nature and may require unforeseen adjustments.
# - The Testing Phase and Bug Fixing may uncover issues that could affect planned schedules. It’s essential to include buffer time in planning.
# - Overall project risks are mitigated by regular check-ins and ensuring deliverables align with stakeholder expectations and functional requirements.
#
# ---
#
# **Conclusion:**
# This estimation report details the expected resources, duration, effort, and risks for each project task, ensuring transparent management of expectations and facilitating project planning. The outlined assumptions and associated risks provide a comprehensive roadmap for a successful and timely website launch.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# **Resource Allocation Chart: Website Project**
#
# | Task                            | Team Member               | Start Date  | End Date    | Notes                                                                                                       |
# |---------------------------------|---------------------------|-------------|------------|-------------------------------------------------------------------------------------------------------------|
# | Project Kickoff and Initial Planning | John Doe (PM)              | Day 1       | Day 1       | Minimal team effort needed. John's leadership will set the tone for the project.                            |
# | Research and Wireframing           | Bob Smith (Designer)       | Day 2       | Day 4       | Requires Bob's creativity and initial design skills.                                                       |
# | Responsive Design Development      | Bob Smith (Designer)       | Day 5       | Day 9       | High effort task suited for Bob due to design skills and understanding of device compatibility.             |
# | User Interface Design              | Bob Smith (Designer)       | Day 10      | Day 13     | Bob continues to ensure aesthetic and functional element integration.                                       |
# | Navigation System Development      | Jane Doe (Software Eng.)   | Day 14      | Day 16     | Medium effort suited for Jane as it involves both design and development.                                   |
# | "About Us" Page Development        | Jane Doe (Software Eng.)   | Day 17      | Day 18     | Simple task with minimal complexity, suitable for Jane's skills.                                            |
# | "Services" Page Development        | Jane Doe (Software Eng.)   | Day 19      | Day 21     | Minimal to moderate complexity, Jane is apt for this standard information-based task.                       |
# | "Contact Us" Page Development      | Jane Doe (Software Eng.)   | Day 22      | Day 25     | Medium effort task requiring Jane's development expertise for map and form integration.                     |
# | Blog Section Implementation        | Jane Doe (Software Eng.)   | Day 26      | Day 30     | Complex task needing Jane's adaptability for future content integration.                                    |
# | Performance Optimization and SEO   | Jane Doe (Software Eng.)   | Day 31      | Day 34     | High effort needing Jane's attention to detail for SEO and performance tuning.                             |
# | Social Media Integration           | Jane Doe (Software Eng.)   | Day 35      | Day 36     | Routine task perfect for Jane, focusing on the standard integration process.                                |
# | Testimonials Section               | Jane Doe (Software Eng.)   | Day 37      | Day 38     | Simple front-end work fitting within Jane's scope of work.                                                  |
# | Testing Phase                      | Alice Johnson & Tom Brown (QA) | Day 39  | Day 43   | Requires both Alice and Tom to ensure a comprehensive evaluation with their combined QA expertise.         |
# | Bug Fixing and Final Adjustments   | Jane Doe (Software Eng.)   | Day 44      | Day 46     | High effort task aligned with Jane's debugging skills, will follow feedback from QA Engineers.             |
# | Project Launch                     | John Doe (PM)               | Day 47      | Day 47     | Minimal effort needed. John to coordinate and ensure all elements align for the project launch.            |
#
# **Summary of Allocation Rationale:**
#
# 1. **John Doe (Project Manager):** Key tasks such as Project Kickoff and Launch are assigned to John due to his high-level oversight capabilities and organizational skills crucial at those pivotal moments.
#
# 2. **Bob Smith (Designer):** With tasks like Research & Wireframing, Responsive Design Development, and UI Design, Bob's schedule capitalizes on his creative prowess, ensuring the design vision is seamless and adjusted to all platforms.
#
# 3. **Jane Doe (Software Engineer):** Assigned to all development tasks, Jane's allocation leverages her coding proficiency efficiently. Her skills are apt for the various complexity levels from simple page developments to complex blog implementations and seamless social media integrations.
#
# 4. **Alice Johnson & Tom Brown (QA Engineers):** Both are involved in the Testing Phase to effectively utilize their QA expertise. This dual allocation ensures a thorough testing process, highlighting any potential bugs pre-launch.
#
# By properly aligning team skills with task requirements and ensuring a balanced workload, we maximize efficiency and maintain a focus on high-quality deliverables, minimizing risks associated with each task. Overall, this strategic distribution promotes successful project completion within proposed timeframes.

# %% [markdown]
# ## Usage Metrics and Costs

# %%
costs = (
    2.5
    * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens)
    / 1_000_000
)
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.model_dump()])
df_usage_metrics
# Out:
# Total costs: $0.0464
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         18576          11098               7478                    9

# %%
crew.usage_metrics
# Out:
# UsageMetrics(total_tokens=18576, prompt_tokens=11098, completion_tokens=7478, successful_requests=9)

# %% [markdown]
# # Result

# %%
result.pydantic.model_dump()
# Out:
# {'tasks': [{'task_name': 'Project Kickoff and Initial Planning',
#    'estimated_time_hours': 8.0,
#    'required_resources': ['John Doe (PM)']},
#   {'task_name': 'Research and Wireframing',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Bob Smith (Designer)']},
#   {'task_name': 'Responsive Design Development',
#    'estimated_time_hours': 32.0,
#    'required_resources': ['Bob Smith (Designer)']},
#   {'task_name': 'User Interface Design',
#    'estimated_time_hours': 32.0,
#    'required_resources': ['Bob Smith (Designer)']},
#   {'task_name': 'Navigation System Development',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe (Software Eng.)']},
#   {'task_name': '"About Us" Page Development',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['Jane Doe (Software Eng.)']},
#   {'task_name': '"Services" Page Development',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe (Software Eng.)']},
#   {'task_name': '"Contact Us" Page Development',
#    'estimated_time_hours': 32.0,
#    'required_resources': ['Jane Doe (Software Eng.)']},
#   {'task_name': 'Blog Section Implementation',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Eng.)']},
#   {'task_name': 'Performance Optimization and SEO',
#    'estimated_time_hours': 32.0,
#    'required_resources': ['Jane Doe (Software Eng.)']},
#   {'task_name': 'Social Media Integration',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['Jane Doe (Software Eng.)']},
#   {'task_name': 'Testimonials Section',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['Jane Doe (Software Eng.)']},
#   {'task_name': 'Testing Phase',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Alice Johnson & Tom Brown (QA)']},
#   {'task_name': 'Bug Fixing and Final Adjustments',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe (Software Eng.)']},
#   {'task_name': 'Project Launch',
#    'estimated_time_hours': 8.0,
#    'required_resources': ['John Doe (PM)']}],
#  'milestones': [{'milestone_name': 'Planning and Design Completion',
#    'tasks': ['Project Kickoff and Initial Planning',
#     'Research and Wireframing',
#     'Responsive Design Development',
#     'User Interface Design']},
#   {'milestone_name': 'Development Completion',
#    'tasks': ['Navigation System Development',
#     '"About Us" Page Development',
#     '"Services" Page Development',
#     '"Contact Us" Page Development',
#     'Blog Section Implementation',
#     'Performance Optimization and SEO',
#     'Social Media Integration',
#     'Testimonials Section']},
#   {'milestone_name': 'Testing and Launch',
#    'tasks': ['Testing Phase',
#     'Bug Fixing and Final Adjustments',
#     'Project Launch']}]}

# %%
tasks = result.pydantic.model_dump()["tasks"]
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption(
    "Task Details"
).set_table_styles([{"selector": "th, td", "props": [("font-size", "120%")]}])
# Out:
# <style type="text/css">
# #T_f93c7 th {
#   font-size: 120%;
# }
# #T_f93c7  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_f93c7" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f93c7_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_f93c7_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_f93c7_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f93c7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f93c7_row0_col0" class="data row0 col0" >Project Kickoff and Initial Planning</td>
#       <td id="T_f93c7_row0_col1" class="data row0 col1" >8.000000</td>
#       <td id="T_f93c7_row0_col2" class="data row0 col2" >['John Doe (PM)']</td>
#     </tr>
#     <tr>
#       <th id="T_f93c7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f93c7_row1_col0" class="data row1 col0" >Research and Wireframing</td>
#       <td id="T_f93c7_row1_col1" class="data row1 col1" >24.000000</td>
#       <td id="T_f93c7_row1_col2" class="data row1 col2" >['Bob Smith (Designer)']</td>
#     </tr>
#     <tr>
#       <th id="T_f93c7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f93c7_row2_col0" class="data row2 col0" >Responsive Design Development</td>
#       <td id="T_f93c7_row2_col1" class="data row2 col1" >32.000000</td>
#       <td id="T_f93c7_row2_col2" class="data row2 col2" >['Bob Smith (Designer)']</td>
#     </tr>
#     <tr>
#       <th id="T_f93c7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f93c7_row3_col0" class="data row3 col0" >User Interface Design</td>
#       <td id="T_f93c7_row3_col1" class="data row3 col1" >32.000000</td>
#       <td id="T_f93c7_row3_col2" class="data row3 col2" >['Bob Smith (Designer)']</td>
#     </tr>
#     <tr>
#       <th id="T_f93c7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f93c7_row4_col0" class="data row4 col0" >Navigation System Development</td>
#       <td id="T_f93c7_row4_col1" class="data row4 col1" >24.000000</td>
#       <td id="T_f93c7_row4_col2" class="data row4 col2" >['Jane Doe (Software Eng.)']</td>
#     </tr>
#     <tr>
#       <th id="T_f93c7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f93c7_row5_col0" class="data row5 col0" >"About Us" Page Development</td>
#       <td id="T_f93c7_row5_col1" class="data row5 col1" >16.000000</td>
#       <td id="T_f93c7_row5_col2" class="data row5 col2" >['Jane Doe (Software Eng.)']</td>
#     </tr>
#     <tr>
#       <th id="T_f93c7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f93c7_row6_col0" class="data row6 col0" >"Services" Page Development</td>
#       <td id="T_f93c7_row6_col1" class="data row6 col1" >24.000000</td>
#       <td id="T_f93c7_row6_col2" class="data row6 col2" >['Jane Doe (Software Eng.)']</td>
#     </tr>
#     <tr>
#       <th id="T_f93c7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f93c7_row7_col0" class="data row7 col0" >"Contact Us" Page Development</td>
#       <td id="T_f93c7_row7_col1" class="data row7 col1" >32.000000</td>
#       <td id="T_f93c7_row7_col2" class="data row7 col2" >['Jane Doe (Software Eng.)']</td>
#     </tr>
#     <tr>
#       <th id="T_f93c7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f93c7_row8_col0" class="data row8 col0" >Blog Section Implementation</td>
#       <td id="T_f93c7_row8_col1" class="data row8 col1" >40.000000</td>
#       <td id="T_f93c7_row8_col2" class="data row8 col2" >['Jane Doe (Software Eng.)']</td>
#     </tr>
#     <tr>
#       <th id="T_f93c7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f93c7_row9_col0" class="data row9 col0" >Performance Optimization and SEO</td>
#       <td id="T_f93c7_row9_col1" class="data row9 col1" >32.000000</td>
#       <td id="T_f93c7_row9_col2" class="data row9 col2" >['Jane Doe (Software Eng.)']</td>
#     </tr>
#     <tr>
#       <th id="T_f93c7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f93c7_row10_col0" class="data row10 col0" >Social Media Integration</td>
#       <td id="T_f93c7_row10_col1" class="data row10 col1" >16.000000</td>
#       <td id="T_f93c7_row10_col2" class="data row10 col2" >['Jane Doe (Software Eng.)']</td>
#     </tr>
#     <tr>
#       <th id="T_f93c7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f93c7_row11_col0" class="data row11 col0" >Testimonials Section</td>
#       <td id="T_f93c7_row11_col1" class="data row11 col1" >16.000000</td>
#       <td id="T_f93c7_row11_col2" class="data row11 col2" >['Jane Doe (Software Eng.)']</td>
#     </tr>
#     <tr>
#       <th id="T_f93c7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f93c7_row12_col0" class="data row12 col0" >Testing Phase</td>
#       <td id="T_f93c7_row12_col1" class="data row12 col1" >40.000000</td>
#       <td id="T_f93c7_row12_col2" class="data row12 col2" >['Alice Johnson & Tom Brown (QA)']</td>
#     </tr>
#     <tr>
#       <th id="T_f93c7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f93c7_row13_col0" class="data row13 col0" >Bug Fixing and Final Adjustments</td>
#       <td id="T_f93c7_row13_col1" class="data row13 col1" >24.000000</td>
#       <td id="T_f93c7_row13_col2" class="data row13 col2" >['Jane Doe (Software Eng.)']</td>
#     </tr>
#     <tr>
#       <th id="T_f93c7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f93c7_row14_col0" class="data row14 col0" >Project Launch</td>
#       <td id="T_f93c7_row14_col1" class="data row14 col1" >8.000000</td>
#       <td id="T_f93c7_row14_col2" class="data row14 col2" >['John Doe (PM)']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Milestones

# %%
milestones = result.pydantic.model_dump()["milestones"]
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption(
    "Task Details"
).set_table_styles([{"selector": "th, td", "props": [("font-size", "120%")]}])
# Out:
# <style type="text/css">
# #T_1e428 th {
#   font-size: 120%;
# }
# #T_1e428  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_1e428" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e428_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_1e428_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e428_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1e428_row0_col0" class="data row0 col0" >Planning and Design Completion</td>
#       <td id="T_1e428_row0_col1" class="data row0 col1" >['Project Kickoff and Initial Planning', 'Research and Wireframing', 'Responsive Design Development', 'User Interface Design']</td>
#     </tr>
#     <tr>
#       <th id="T_1e428_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1e428_row1_col0" class="data row1 col0" >Development Completion</td>
#       <td id="T_1e428_row1_col1" class="data row1 col1" >['Navigation System Development', '"About Us" Page Development', '"Services" Page Development', '"Contact Us" Page Development', 'Blog Section Implementation', 'Performance Optimization and SEO', 'Social Media Integration', 'Testimonials Section']</td>
#     </tr>
#     <tr>
#       <th id="T_1e428_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1e428_row2_col0" class="data row2 col0" >Testing and Launch</td>
#       <td id="T_1e428_row2_col1" class="data row2 col1" >['Testing Phase', 'Bug Fixing and Final Adjustments', 'Project Launch']</td>
#     </tr>
#   </tbody>
# </table>
